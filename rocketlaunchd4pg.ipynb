# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Select the Runtime > "Change runtime type" menu to enable a GPU accelerator, ')
  print('and then re-execute this cell.')
else:
  print(gpu_info)

from psutil import virtual_memory
ram_gb = virtual_memory().total / 1e9
print('Your runtime has {:.1f} gigabytes of available RAM\n'.format(ram_gb))

if ram_gb < 20:
  print('To enable a high-RAM runtime, select the Runtime > "Change runtime type"')
  print('menu, and then select High-RAM in the Runtime shape dropdown. Then, ')
  print('re-execute this cell.')
else:
  print('You are using a high-RAM runtime!')
# Out:
# Fri Jun 26 08:21:16 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 450.36.06    Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   37C    P0    26W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                 ERR! |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+
# Your runtime has 27.4 gigabytes of available RAM
#
# You are using a high-RAM runtime!

# %%
# !pip install ptan tensorboardX box2D
# !pip uninstall pyglet- y
# !pip install pyglet==v1.3.2
# Out:
# Requirement already satisfied: ptan in /usr/local/lib/python3.6/dist-packages (0.6)
# Requirement already satisfied: tensorboardX in /usr/local/lib/python3.6/dist-packages (2.0)
# Requirement already satisfied: box2D in /usr/local/lib/python3.6/dist-packages (2.3.10)
# Requirement already satisfied: atari-py in /usr/local/lib/python3.6/dist-packages (from ptan) (0.2.6)
# Requirement already satisfied: torch==1.3.0 in /usr/local/lib/python3.6/dist-packages (from ptan) (1.3.0)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.6/dist-packages (from ptan) (4.1.2.30)
# Requirement already satisfied: gym in /usr/local/lib/python3.6/dist-packages (from ptan) (0.17.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from ptan) (1.18.5)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from tensorboardX) (1.12.0)
# Requirement already satisfied: protobuf>=3.8.0 in /usr/local/lib/python3.6/dist-packages (from tensorboardX) (3.10.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.6/dist-packages (from gym->ptan) (1.4.1)
# Requirement already satisfied: cloudpickle<1.4.0,>=1.2.0 in /usr/local/lib/python3.6/dist-packages (from gym->ptan) (1.3.0)
# Collecting pyglet<=1.5.0,>=1.4.0
#   Using cached https://files.pythonhosted.org/packages/70/ca/20aee170afe6011e295e34b27ad7d7ccd795faba581dd3c6f7cec237f561/pyglet-1.5.0-py2.py3-none-any.whl
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from protobuf>=3.8.0->tensorboardX) (47.3.1)
# Requirement already satisfied: future in /usr/local/lib/python3.6/dist-packages (from pyglet<=1.5.0,>=1.4.0->gym->ptan) (0.16.0)
# Installing collected packages: pyglet
#   Found existing installation: pyglet 1.3.2
#     Uninstalling pyglet-1.3.2:
#       Successfully uninstalled pyglet-1.3.2
# Successfully installed pyglet-1.5.0
# Uninstalling pyglet-1.5.0:
#   Would remove:
#     /usr/local/lib/python3.6/dist-packages/pyglet-1.5.0.dist-info/*
#     /usr/local/lib/python3.6/dist-packages/pyglet/*
# Proceed (y/n)? y
#   Successfully uninstalled pyglet-1.5.0
# Collecting pyglet==v1.3.2
#   Using cached https://files.pythonhosted.org/packages/1c/fc/dad5eaaab68f0c21e2f906a94ddb98175662cc5a654eee404d59554ce0fa/pyglet-1.3.2-py2.py3-none-any.whl
# Requirement already satisfied: future in /usr/local/lib/python3.6/dist-packages (from pyglet==v1.3.2) (0.16.0)
# ERROR: gym 0.17.2 has requirement pyglet<=1.5.0,>=1.4.0, but you'll have pyglet 1.3.2 which is incompatible.
# Installing collected packages: pyglet
# Successfully installed pyglet-1.3.2

# %% [markdown]
# **Python Packages**

# %%
# !git clone https://github.com/ugurkanates/SpaceXReinforcementLearning.git
# %cd SpaceXReinforcementLearning
# !ls
# Out:
# fatal: destination path 'SpaceXReinforcementLearning' already exists and is not an empty directory.
# /content/SpaceXReinforcementLearning
# 02_play.py	     keyboard_agent.py	saves
# adamPPO		     lib		scripts
# bin		     libSAC		setup.py
# CODE_OF_CONDUCT.rst  LICENSE.md		SpaceXReinforcementLearning
# d4pg.py		     py.Dockerfile	test.py
# docs		     README.md		tests
# examples	     roketvideotest1	vendor
# fak.dat		     runs
# gym		     sac_train.py

# %% [markdown]
# google upload test

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# !apt install python-opengl
# !apt install ffmpeg
# !apt install xvfb
# !pip3 install pyvirtualdisplay

# Virtual display
from pyvirtualdisplay import Display

virtual_display = Display(visible=0, size=(1400, 900))
virtual_display.start()
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# python-opengl is already the newest version (3.1.0+dfsg-1).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-440
# Use 'apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 59 not upgraded.
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# ffmpeg is already the newest version (7:3.4.6-0ubuntu0.18.04.1).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-440
# Use 'apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 59 not upgraded.
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# xvfb is already the newest version (2:1.19.6-1ubuntu4.4).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-440
# Use 'apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 59 not upgraded.
# Requirement already satisfied: pyvirtualdisplay in /usr/local/lib/python3.6/dist-packages (1.3.2)
# Requirement already satisfied: EasyProcess in /usr/local/lib/python3.6/dist-packages (from pyvirtualdisplay) (0.3)

# %%
ENV_ID = "RocketLander-v0"
#!/usr/bin/env python3
import os
import ptan
import time
import gym
import argparse
from tensorboardX import SummaryWriter
import numpy as np

from lib import model, common

import torch
import torch.optim as optim
import torch.nn.functional as F


GAMMA = 0.99
BATCH_SIZE = 64
LEARNING_RATE = 1e-4
REPLAY_SIZE = 100000
REPLAY_INITIAL = 10000
REWARD_STEPS = 5

TEST_ITERS = 1000

Vmax = 10
Vmin = -10
N_ATOMS = 51
DELTA_Z = (Vmax - Vmin) / (N_ATOMS - 1)
RETURN_TRAIN = False
actor_saved_net = "/content/gdrive/My Drive/colab_model/rocket/d4pg/run1/actor.dat"
critic_saved_net = "/content/gdrive/My Drive/colab_model/rocket/d4pg/run1/critic.dat"
def test_net(net, env, count=10, device="cpu"):
    rewards = 0.0
    steps = 0
    for _ in range(count):
        obs = env.reset()
        while True:
            obs_v = ptan.agent.float32_preprocessor([obs]).to(device)
            mu_v = net(obs_v)
            action = mu_v.squeeze(dim=0).data.cpu().numpy()
            action = np.clip(action, -1, 1)
            obs, reward, done, _ = env.step(action)
            rewards += reward
            steps += 1
            if done:
                break
    return rewards / count, steps / count


def distr_projection(next_distr_v, rewards_v, dones_mask_t,
                     gamma, device="cpu"):
    next_distr = next_distr_v.data.cpu().numpy()
    rewards = rewards_v.data.cpu().numpy()
    dones_mask = dones_mask_t.cpu().numpy().astype(np.bool)
    batch_size = len(rewards)
    proj_distr = np.zeros((batch_size, N_ATOMS), dtype=np.float32)

    for atom in range(N_ATOMS):
        tz_j = np.minimum(Vmax, np.maximum(
            Vmin, rewards + (Vmin + atom * DELTA_Z) * gamma))
        b_j = (tz_j - Vmin) / DELTA_Z
        l = np.floor(b_j).astype(np.int64)
        u = np.ceil(b_j).astype(np.int64)
        eq_mask = u == l
        proj_distr[eq_mask, l[eq_mask]] += \
            next_distr[eq_mask, atom]
        ne_mask = u != l
        proj_distr[ne_mask, l[ne_mask]] += \
            next_distr[ne_mask, atom] * (u - b_j)[ne_mask]
        proj_distr[ne_mask, u[ne_mask]] += \
            next_distr[ne_mask, atom] * (b_j - l)[ne_mask]

    if dones_mask.any():
        proj_distr[dones_mask] = 0.0
        tz_j = np.minimum(Vmax, np.maximum(
            Vmin, rewards[dones_mask]))
        b_j = (tz_j - Vmin) / DELTA_Z
        l = np.floor(b_j).astype(np.int64)
        u = np.ceil(b_j).astype(np.int64)
        eq_mask = u == l
        eq_dones = dones_mask.copy()
        eq_dones[dones_mask] = eq_mask
        if eq_dones.any():
            proj_distr[eq_dones, l[eq_mask]] = 1.0
        ne_mask = u != l
        ne_dones = dones_mask.copy()
        ne_dones[dones_mask] = ne_mask
        if ne_dones.any():
            proj_distr[ne_dones, l[ne_mask]] = (u - b_j)[ne_mask]
            proj_distr[ne_dones, u[ne_mask]] = (b_j - l)[ne_mask]
    return torch.FloatTensor(proj_distr).to(device)


def main():
    parser = argparse.ArgumentParser()
    name = "test_rocket_d4pg"
    device = torch.device("cuda")

    save_path = os.path.join("saves", "d4pg-" + name)
    os.makedirs(save_path, exist_ok=True)

    env = gym.make(ENV_ID)
    directory = './roketvideotest1/'
    env = gym.wrappers.Monitor(env, directory,force=True)
    test_env = gym.make(ENV_ID)

    act_net = model.DDPGActor(env.observation_space.shape[0], env.action_space.shape[0]).to(device)
    crt_net = model.D4PGCritic(env.observation_space.shape[0], env.action_space.shape[0], N_ATOMS, Vmin, Vmax).to(device)
    if RETURN_TRAIN == True:
      act_net.load_state_dict(torch.load(args.model))
      crt_net.load_state_dict(torch.load(args.model))

    print(act_net)
    print(crt_net)
    tgt_act_net = ptan.agent.TargetNet(act_net)
    tgt_crt_net = ptan.agent.TargetNet(crt_net)

    writer = SummaryWriter(comment="-d4pg_" + name)
    agent = model.AgentDDPG(act_net, device=device)
    exp_source = ptan.experience.ExperienceSourceFirstLast(env, agent, gamma=GAMMA, steps_count=REWARD_STEPS)
    buffer = ptan.experience.ExperienceReplayBuffer(exp_source, buffer_size=REPLAY_SIZE)
    act_opt = optim.Adam(act_net.parameters(), lr=LEARNING_RATE)
    crt_opt = optim.Adam(crt_net.parameters(), lr=LEARNING_RATE)

    frame_idx = 0
    best_reward = None
    with ptan.common.utils.RewardTracker(writer) as tracker:
        with ptan.common.utils.TBMeanTracker(writer, batch_size=10) as tb_tracker:
            while True:
                frame_idx += 1
                buffer.populate(1)
                rewards_steps = exp_source.pop_rewards_steps()
                if rewards_steps:
                    rewards, steps = zip(*rewards_steps)
                    tb_tracker.track("episode_steps", steps[0], frame_idx)
                    tracker.reward(rewards[0], frame_idx)

                if len(buffer) < REPLAY_INITIAL:
                    continue

                batch = buffer.sample(BATCH_SIZE)
                states_v, actions_v, rewards_v, \
                dones_mask, last_states_v = \
                    common.unpack_batch_ddqn(batch, device)

                # train critic
                crt_opt.zero_grad()
                crt_distr_v = crt_net(states_v, actions_v)
                last_act_v = tgt_act_net.target_model(
                    last_states_v)
                last_distr_v = F.softmax(
                    tgt_crt_net.target_model(
                        last_states_v, last_act_v), dim=1)
                proj_distr_v = distr_projection(
                    last_distr_v, rewards_v, dones_mask,
                    gamma=GAMMA**REWARD_STEPS, device=device)
                prob_dist_v = -F.log_softmax(
                    crt_distr_v, dim=1) * proj_distr_v
                critic_loss_v = prob_dist_v.sum(dim=1).mean()
                critic_loss_v.backward()
                crt_opt.step()
                tb_tracker.track("loss_critic", critic_loss_v, frame_idx)

                # train actor
                act_opt.zero_grad()
                cur_actions_v = act_net(states_v)
                crt_distr_v = crt_net(states_v, cur_actions_v)
                actor_loss_v = -crt_net.distr_to_q(crt_distr_v)
                actor_loss_v = actor_loss_v.mean()
                actor_loss_v.backward()
                act_opt.step()
                tb_tracker.track("loss_actor", actor_loss_v,
                                 frame_idx)

                tgt_act_net.alpha_sync(alpha=1 - 1e-3)
                tgt_crt_net.alpha_sync(alpha=1 - 1e-3)

                if frame_idx % TEST_ITERS == 0:
                    ts = time.time()
                    rewards, steps = test_net(act_net, test_env, device=device)
                    print("Test done in %.2f sec, reward %.3f, steps %d" % (
                        time.time() - ts, rewards, steps))
                    writer.add_scalar("test_reward", rewards, frame_idx)
                    writer.add_scalar("test_steps", steps, frame_idx)
                 
                    if best_reward is None or best_reward < rewards:
                        if best_reward is not None:
                            print("Best reward updated: %.3f -> %.3f" % (best_reward, rewards))
                            name = "best_%+.3f_%d.dat" % (rewards, frame_idx)
                            fname_actor = os.path.join(save_path,"actor"+name)
                            fname_critic = os.path.join(save_path,"critic"+name)
                            torch.save(act_net.state_dict(),fname_actor)
                            torch.save(crt_net.state_dict,fname_critic)
                            # !cp fname_actor "/content/gdrive/My Drive/colab_model/rocket/d4pg/run1/" # copies file to google drive
                            # !cp fname_critic "/content/gdrive/My Drive/colab_model/rocket/d4pg/run1/" # copies file to google drive


                        best_reward = rewards

    pass

# %%
main()
# Out:
# Streaming output truncated to the last 5000 lines.
# Test done in 5.32 sec, reward -3.899, steps 946
# 3430319: done 4834 episodes, mean reward -3.430, speed 48.53 f/s
# Test done in 5.60 sec, reward -3.894, steps 1000
# 3431319: done 4835 episodes, mean reward -3.422, speed 70.85 f/s
# Test done in 3.96 sec, reward -3.213, steps 706
# 3432319: done 4836 episodes, mean reward -3.416, speed 80.65 f/s
# 3432722: done 4837 episodes, mean reward -3.406, speed 118.12 f/s
# Test done in 4.06 sec, reward -3.333, steps 721
# 3433550: done 4838 episodes, mean reward -3.404, speed 75.04 f/s
# 3433891: done 4839 episodes, mean reward -3.376, speed 118.41 f/s
# Test done in 3.57 sec, reward -3.045, steps 639
# 3434891: done 4840 episodes, mean reward -3.373, speed 83.59 f/s
# Test done in 4.51 sec, reward -3.560, steps 806
# 3435891: done 4841 episodes, mean reward -3.372, speed 77.66 f/s
# Test done in 3.93 sec, reward -3.076, steps 702
# 3436243: done 4842 episodes, mean reward -3.360, speed 51.01 f/s
# Test done in 3.75 sec, reward -2.950, steps 664
# 3437243: done 4843 episodes, mean reward -3.370, speed 82.14 f/s
# Test done in 4.32 sec, reward -3.456, steps 776
# 3438243: done 4844 episodes, mean reward -3.395, speed 79.17 f/s
# 3438648: done 4845 episodes, mean reward -3.372, speed 120.14 f/s
# Test done in 4.93 sec, reward -3.802, steps 879
# 3439127: done 4846 episodes, mean reward -3.354, speed 53.68 f/s
# 3439510: done 4847 episodes, mean reward -3.346, speed 120.05 f/s
# Test done in 4.47 sec, reward -3.976, steps 795
# 3440510: done 4848 episodes, mean reward -3.351, speed 78.35 f/s
# Test done in 4.14 sec, reward -3.364, steps 743
# 3441510: done 4849 episodes, mean reward -3.361, speed 80.27 f/s
# Test done in 4.36 sec, reward -3.458, steps 774
# 3442510: done 4850 episodes, mean reward -3.381, speed 78.88 f/s
# 3442861: done 4851 episodes, mean reward -3.382, speed 118.83 f/s
# Test done in 4.73 sec, reward -3.638, steps 831
# 3443228: done 4852 episodes, mean reward -3.364, speed 46.56 f/s
# Test done in 4.80 sec, reward -3.663, steps 859
# 3444228: done 4853 episodes, mean reward -3.355, speed 75.54 f/s
# Test done in 4.23 sec, reward -3.189, steps 753
# 3445228: done 4854 episodes, mean reward -3.372, speed 79.54 f/s
# 3445719: done 4855 episodes, mean reward -3.372, speed 119.95 f/s
# Test done in 5.17 sec, reward -3.603, steps 905
# 3446082: done 4856 episodes, mean reward -3.351, speed 43.80 f/s
# 3446524: done 4857 episodes, mean reward -3.334, speed 115.74 f/s
# Test done in 5.57 sec, reward -3.880, steps 1000
# 3447524: done 4858 episodes, mean reward -3.345, speed 71.94 f/s
# Test done in 5.14 sec, reward -3.710, steps 912
# 3448036: done 4859 episodes, mean reward -3.341, speed 54.41 f/s
# Test done in 5.65 sec, reward -3.743, steps 1000
# 3449036: done 4860 episodes, mean reward -3.338, speed 71.21 f/s
# Test done in 4.23 sec, reward -3.387, steps 757
# 3450036: done 4861 episodes, mean reward -3.334, speed 79.61 f/s
# Test done in 4.98 sec, reward -3.850, steps 889
# 3451036: done 4862 episodes, mean reward -3.345, speed 75.18 f/s
# Test done in 4.52 sec, reward -3.366, steps 805
# 3452036: done 4863 episodes, mean reward -3.360, speed 77.84 f/s
# Test done in 6.60 sec, reward -3.483, steps 835
# 3453036: done 4864 episodes, mean reward -3.360, speed 66.41 f/s
# Test done in 5.28 sec, reward -3.836, steps 943
# 3454036: done 4865 episodes, mean reward -3.362, speed 73.52 f/s
# Test done in 5.08 sec, reward -3.521, steps 891
# 3455036: done 4866 episodes, mean reward -3.358, speed 74.23 f/s
# 3455385: done 4867 episodes, mean reward -3.357, speed 119.45 f/s
# Test done in 5.45 sec, reward -4.011, steps 979
# 3456385: done 4868 episodes, mean reward -3.339, speed 72.54 f/s
# Test done in 4.68 sec, reward -3.562, steps 834
# 3457385: done 4869 episodes, mean reward -3.356, speed 77.04 f/s
# Test done in 4.55 sec, reward -3.521, steps 810
# 3458385: done 4870 episodes, mean reward -3.374, speed 77.83 f/s
# Test done in 4.90 sec, reward -3.691, steps 876
# 3459352: done 4871 episodes, mean reward -3.375, speed 74.75 f/s
# Test done in 4.20 sec, reward -3.364, steps 753
# 3460352: done 4872 episodes, mean reward -3.373, speed 79.55 f/s
# 3460737: done 4873 episodes, mean reward -3.365, speed 119.24 f/s
# Test done in 4.17 sec, reward -3.346, steps 737
# 3461276: done 4874 episodes, mean reward -3.336, speed 61.74 f/s
# Test done in 4.58 sec, reward -3.743, steps 820
# 3462276: done 4875 episodes, mean reward -3.332, speed 77.37 f/s
# 3462734: done 4876 episodes, mean reward -3.335, speed 119.90 f/s
# Test done in 3.70 sec, reward -3.501, steps 659
# 3463734: done 4877 episodes, mean reward -3.350, speed 83.37 f/s
# Test done in 4.72 sec, reward -3.622, steps 844
# 3464665: done 4878 episodes, mean reward -3.374, speed 74.30 f/s
# Test done in 4.32 sec, reward -3.841, steps 768
# 3465665: done 4879 episodes, mean reward -3.373, speed 79.07 f/s
# Test done in 4.65 sec, reward -3.627, steps 815
# 3466008: done 4880 episodes, mean reward -3.354, speed 45.69 f/s
# Test done in 4.90 sec, reward -3.966, steps 861
# 3467008: done 4881 episodes, mean reward -3.368, speed 75.25 f/s
# Test done in 4.34 sec, reward -3.805, steps 775
# 3468008: done 4882 episodes, mean reward -3.354, speed 78.40 f/s
# 3468442: done 4883 episodes, mean reward -3.339, speed 120.91 f/s
# 3468825: done 4884 episodes, mean reward -3.319, speed 119.39 f/s
# Test done in 4.31 sec, reward -3.702, steps 766
# 3469067: done 4885 episodes, mean reward -3.311, speed 38.21 f/s
# Test done in 4.09 sec, reward -3.793, steps 707
# 3470067: done 4886 episodes, mean reward -3.330, speed 78.38 f/s
# 3470810: done 4887 episodes, mean reward -3.331, speed 120.33 f/s
# Test done in 4.36 sec, reward -3.483, steps 777
# 3471120: done 4888 episodes, mean reward -3.328, speed 44.68 f/s
# Test done in 4.67 sec, reward -3.875, steps 829
# 3472120: done 4889 episodes, mean reward -3.330, speed 76.90 f/s
# Test done in 3.41 sec, reward -3.420, steps 607
# 3473120: done 4890 episodes, mean reward -3.336, speed 85.19 f/s
# Test done in 4.68 sec, reward -3.948, steps 826
# 3474120: done 4891 episodes, mean reward -3.359, speed 76.51 f/s
# Test done in 4.42 sec, reward -4.114, steps 791
# 3475120: done 4892 episodes, mean reward -3.377, speed 78.34 f/s
# 3475549: done 4893 episodes, mean reward -3.361, speed 119.83 f/s
# Test done in 4.23 sec, reward -3.673, steps 757
# 3476549: done 4894 episodes, mean reward -3.377, speed 79.79 f/s
# Test done in 3.05 sec, reward -3.468, steps 540
# 3477549: done 4895 episodes, mean reward -3.398, speed 88.12 f/s
# 3477954: done 4896 episodes, mean reward -3.397, speed 120.31 f/s
# Test done in 4.35 sec, reward -4.152, steps 781
# 3478954: done 4897 episodes, mean reward -3.402, speed 78.81 f/s
# Test done in 4.23 sec, reward -3.742, steps 758
# 3479954: done 4898 episodes, mean reward -3.408, speed 79.34 f/s
# Test done in 4.25 sec, reward -3.697, steps 752
# 3480954: done 4899 episodes, mean reward -3.420, speed 78.95 f/s
# Test done in 4.36 sec, reward -3.803, steps 782
# 3481683: done 4900 episodes, mean reward -3.426, speed 69.78 f/s
# Test done in 4.13 sec, reward -3.717, steps 736
# 3482605: done 4901 episodes, mean reward -3.445, speed 78.25 f/s
# Test done in 4.09 sec, reward -3.549, steps 730
# 3483605: done 4902 episodes, mean reward -3.465, speed 80.58 f/s
# 3483915: done 4903 episodes, mean reward -3.456, speed 120.00 f/s
# Test done in 3.37 sec, reward -3.089, steps 602
# 3484915: done 4904 episodes, mean reward -3.451, speed 85.80 f/s
# Test done in 3.81 sec, reward -3.566, steps 680
# 3485185: done 4905 episodes, mean reward -3.450, speed 44.55 f/s
# Test done in 3.96 sec, reward -3.456, steps 707
# 3486087: done 4906 episodes, mean reward -3.477, speed 78.65 f/s
# 3486404: done 4907 episodes, mean reward -3.465, speed 118.63 f/s
# 3486739: done 4908 episodes, mean reward -3.447, speed 118.46 f/s
# Test done in 3.84 sec, reward -3.440, steps 676
# 3487038: done 4909 episodes, mean reward -3.437, speed 46.92 f/s
# Test done in 3.14 sec, reward -3.281, steps 562
# 3488038: done 4910 episodes, mean reward -3.442, speed 87.38 f/s
# 3488338: done 4911 episodes, mean reward -3.438, speed 120.77 f/s
# 3488774: done 4912 episodes, mean reward -3.444, speed 119.55 f/s
# Test done in 4.20 sec, reward -4.103, steps 749
# 3489480: done 4913 episodes, mean reward -3.464, speed 70.06 f/s
# Test done in 4.32 sec, reward -3.699, steps 770
# 3490480: done 4914 episodes, mean reward -3.463, speed 78.87 f/s
# Test done in 4.72 sec, reward -3.864, steps 851
# 3491480: done 4915 episodes, mean reward -3.471, speed 76.44 f/s
# 3491803: done 4916 episodes, mean reward -3.471, speed 120.48 f/s
# Test done in 4.03 sec, reward -3.397, steps 723
# 3492103: done 4917 episodes, mean reward -3.449, speed 45.94 f/s
# 3492506: done 4918 episodes, mean reward -3.446, speed 120.10 f/s
# 3492879: done 4919 episodes, mean reward -3.427, speed 119.91 f/s
# Test done in 4.02 sec, reward -3.440, steps 708
# 3493879: done 4920 episodes, mean reward -3.434, speed 80.51 f/s
# Test done in 4.66 sec, reward -3.630, steps 833
# 3494802: done 4921 episodes, mean reward -3.443, speed 73.43 f/s
# Test done in 4.19 sec, reward -3.702, steps 734
# 3495711: done 4922 episodes, mean reward -3.459, speed 77.20 f/s
# Test done in 4.11 sec, reward -3.394, steps 739
# 3496711: done 4923 episodes, mean reward -3.463, speed 80.55 f/s
# Test done in 4.59 sec, reward -3.818, steps 819
# 3497430: done 4924 episodes, mean reward -3.467, speed 68.13 f/s
# Test done in 4.83 sec, reward -4.046, steps 869
# 3498430: done 4925 episodes, mean reward -3.474, speed 75.79 f/s
# Test done in 3.76 sec, reward -3.328, steps 669
# 3499430: done 4926 episodes, mean reward -3.492, speed 82.52 f/s
# 3499713: done 4927 episodes, mean reward -3.481, speed 118.58 f/s
# Test done in 4.47 sec, reward -3.722, steps 797
# 3500713: done 4928 episodes, mean reward -3.491, speed 78.22 f/s
# Test done in 4.31 sec, reward -3.934, steps 775
# 3501105: done 4929 episodes, mean reward -3.490, speed 51.70 f/s
# 3501452: done 4930 episodes, mean reward -3.490, speed 121.02 f/s
# Test done in 4.29 sec, reward -3.274, steps 765
# 3502452: done 4931 episodes, mean reward -3.483, speed 79.41 f/s
# Test done in 5.25 sec, reward -4.159, steps 935
# 3503446: done 4932 episodes, mean reward -3.503, speed 73.56 f/s
# Test done in 4.11 sec, reward -3.751, steps 738
# 3504024: done 4933 episodes, mean reward -3.497, speed 64.84 f/s
# Test done in 4.98 sec, reward -3.881, steps 899
# 3505024: done 4934 episodes, mean reward -3.515, speed 75.19 f/s
# 3505353: done 4935 episodes, mean reward -3.498, speed 121.40 f/s
# Test done in 4.50 sec, reward -3.570, steps 796
# 3506353: done 4936 episodes, mean reward -3.505, speed 77.49 f/s
# Test done in 4.80 sec, reward -3.858, steps 853
# 3507353: done 4937 episodes, mean reward -3.528, speed 76.44 f/s
# 3507645: done 4938 episodes, mean reward -3.510, speed 119.59 f/s
# Test done in 4.93 sec, reward -3.916, steps 878
# 3508645: done 4939 episodes, mean reward -3.526, speed 75.33 f/s
# 3508985: done 4940 episodes, mean reward -3.522, speed 120.17 f/s
# Test done in 5.56 sec, reward -4.092, steps 1000
# 3509425: done 4941 episodes, mean reward -3.508, speed 47.64 f/s
# 3509720: done 4942 episodes, mean reward -3.506, speed 120.74 f/s
# Test done in 4.83 sec, reward -3.878, steps 868
# 3510720: done 4943 episodes, mean reward -3.513, speed 76.13 f/s
# Test done in 4.32 sec, reward -3.678, steps 774
# 3511720: done 4944 episodes, mean reward -3.517, speed 78.78 f/s
# Test done in 5.31 sec, reward -3.987, steps 932
# 3512720: done 4945 episodes, mean reward -3.532, speed 73.30 f/s
# Test done in 4.26 sec, reward -3.222, steps 761
# 3513720: done 4946 episodes, mean reward -3.552, speed 79.42 f/s
# Test done in 4.47 sec, reward -3.637, steps 793
# 3514720: done 4947 episodes, mean reward -3.573, speed 77.79 f/s
# Test done in 5.11 sec, reward -4.206, steps 919
# 3515720: done 4948 episodes, mean reward -3.567, speed 74.59 f/s
# Test done in 4.19 sec, reward -3.611, steps 749
# 3516089: done 4949 episodes, mean reward -3.549, speed 50.79 f/s
# Test done in 4.71 sec, reward -3.921, steps 835
# 3517053: done 4950 episodes, mean reward -3.559, speed 75.64 f/s
# Test done in 4.31 sec, reward -3.533, steps 762
# 3518053: done 4951 episodes, mean reward -3.574, speed 79.06 f/s
# 3518527: done 4952 episodes, mean reward -3.572, speed 115.39 f/s
# Test done in 4.63 sec, reward -3.588, steps 809
# 3519527: done 4953 episodes, mean reward -3.580, speed 76.27 f/s
# Test done in 4.90 sec, reward -4.485, steps 875
# 3520453: done 4954 episodes, mean reward -3.595, speed 73.51 f/s
# 3520736: done 4955 episodes, mean reward -3.594, speed 119.89 f/s
# Test done in 4.14 sec, reward -3.557, steps 739
# 3521736: done 4956 episodes, mean reward -3.617, speed 80.07 f/s
# Test done in 4.34 sec, reward -3.785, steps 774
# 3522131: done 4957 episodes, mean reward -3.615, speed 51.59 f/s
# Test done in 4.58 sec, reward -3.455, steps 818
# 3523131: done 4958 episodes, mean reward -3.619, speed 77.48 f/s
# Test done in 4.47 sec, reward -3.335, steps 785
# 3524131: done 4959 episodes, mean reward -3.645, speed 78.40 f/s
# Test done in 3.71 sec, reward -3.120, steps 661
# 3525131: done 4960 episodes, mean reward -3.648, speed 82.45 f/s
# 3525459: done 4961 episodes, mean reward -3.632, speed 119.70 f/s
# 3525855: done 4962 episodes, mean reward -3.615, speed 120.42 f/s
# Test done in 3.86 sec, reward -3.442, steps 692
# 3526185: done 4963 episodes, mean reward -3.606, speed 49.92 f/s
# Test done in 2.70 sec, reward -2.838, steps 471
# 3527185: done 4964 episodes, mean reward -3.606, speed 90.58 f/s
# 3527520: done 4965 episodes, mean reward -3.594, speed 119.83 f/s
# Test done in 3.63 sec, reward -3.441, steps 647
# 3528520: done 4966 episodes, mean reward -3.596, speed 83.59 f/s
# Test done in 4.31 sec, reward -3.405, steps 773
# 3529520: done 4967 episodes, mean reward -3.618, speed 79.23 f/s
# Test done in 3.91 sec, reward -3.113, steps 695
# 3530520: done 4968 episodes, mean reward -3.620, speed 81.61 f/s
# 3530948: done 4969 episodes, mean reward -3.608, speed 119.19 f/s
# Test done in 4.18 sec, reward -3.387, steps 738
# 3531948: done 4970 episodes, mean reward -3.608, speed 79.57 f/s
# Test done in 4.55 sec, reward -3.530, steps 813
# 3532252: done 4971 episodes, mean reward -3.586, speed 42.92 f/s
# Test done in 3.29 sec, reward -3.249, steps 582
# 3533161: done 4972 episodes, mean reward -3.600, speed 83.68 f/s
# Test done in 3.79 sec, reward -3.365, steps 678
# 3534161: done 4973 episodes, mean reward -3.609, speed 82.41 f/s
# Test done in 4.08 sec, reward -3.381, steps 729
# 3535161: done 4974 episodes, mean reward -3.623, speed 80.44 f/s
# 3535441: done 4975 episodes, mean reward -3.610, speed 120.16 f/s
# 3535717: done 4976 episodes, mean reward -3.607, speed 120.23 f/s
# 3535997: done 4977 episodes, mean reward -3.586, speed 120.38 f/s
# Test done in 3.39 sec, reward -2.981, steps 600
# 3536319: done 4978 episodes, mean reward -3.563, speed 52.78 f/s
# 3536686: done 4979 episodes, mean reward -3.551, speed 120.16 f/s
# 3536970: done 4980 episodes, mean reward -3.554, speed 119.93 f/s
# Test done in 3.82 sec, reward -3.078, steps 681
# 3537970: done 4981 episodes, mean reward -3.561, speed 81.62 f/s
# Test done in 3.73 sec, reward -3.159, steps 664
# 3538348: done 4982 episodes, mean reward -3.546, speed 54.86 f/s
# 3538669: done 4983 episodes, mean reward -3.548, speed 118.95 f/s
# Test done in 4.61 sec, reward -3.321, steps 820
# 3539669: done 4984 episodes, mean reward -3.565, speed 76.93 f/s
# Test done in 4.14 sec, reward -3.297, steps 742
# 3540031: done 4985 episodes, mean reward -3.565, speed 50.58 f/s
# Test done in 4.58 sec, reward -3.372, steps 814
# 3541031: done 4986 episodes, mean reward -3.566, speed 77.63 f/s
# Test done in 4.79 sec, reward -4.020, steps 852
# 3542031: done 4987 episodes, mean reward -3.570, speed 76.13 f/s
# Test done in 4.24 sec, reward -3.820, steps 757
# 3543031: done 4988 episodes, mean reward -3.590, speed 79.53 f/s
# Test done in 4.29 sec, reward -3.407, steps 748
# 3544031: done 4989 episodes, mean reward -3.592, speed 77.38 f/s
# 3544405: done 4990 episodes, mean reward -3.582, speed 118.80 f/s
# Test done in 3.61 sec, reward -2.921, steps 644
# 3545332: done 4991 episodes, mean reward -3.591, speed 81.86 f/s
# Test done in 4.70 sec, reward -3.440, steps 835
# 3546332: done 4992 episodes, mean reward -3.585, speed 76.81 f/s
# 3546752: done 4993 episodes, mean reward -3.584, speed 119.80 f/s
# Test done in 3.33 sec, reward -3.206, steps 592
# 3547110: done 4994 episodes, mean reward -3.566, speed 56.59 f/s
# 3547400: done 4995 episodes, mean reward -3.550, speed 120.61 f/s
# 3547799: done 4996 episodes, mean reward -3.558, speed 120.08 f/s
# Test done in 4.17 sec, reward -3.435, steps 742
# 3548799: done 4997 episodes, mean reward -3.554, speed 79.99 f/s
# Test done in 3.76 sec, reward -3.218, steps 667
# 3549152: done 4998 episodes, mean reward -3.537, speed 52.45 f/s
# 3549482: done 4999 episodes, mean reward -3.521, speed 118.61 f/s
# Test done in 5.58 sec, reward -4.094, steps 981
# 3550482: done 5000 episodes, mean reward -3.518, speed 70.51 f/s
# Test done in 4.78 sec, reward -3.607, steps 856
# 3551459: done 5001 episodes, mean reward -3.530, speed 38.24 f/s
# 3551786: done 5002 episodes, mean reward -3.506, speed 119.93 f/s
# Test done in 4.25 sec, reward -3.213, steps 762
# 3552786: done 5003 episodes, mean reward -3.519, speed 79.37 f/s
# Test done in 3.92 sec, reward -3.292, steps 696
# 3553070: done 5004 episodes, mean reward -3.503, speed 45.14 f/s
# 3553401: done 5005 episodes, mean reward -3.499, speed 119.98 f/s
# Test done in 3.97 sec, reward -3.120, steps 709
# 3554401: done 5006 episodes, mean reward -3.493, speed 81.11 f/s
# 3554814: done 5007 episodes, mean reward -3.490, speed 118.40 f/s
# Test done in 4.65 sec, reward -3.371, steps 824
# 3555814: done 5008 episodes, mean reward -3.501, speed 76.59 f/s
# Test done in 3.98 sec, reward -3.196, steps 704
# 3556814: done 5009 episodes, mean reward -3.514, speed 80.97 f/s
# Test done in 4.08 sec, reward -3.411, steps 727
# 3557183: done 5010 episodes, mean reward -3.498, speed 51.62 f/s
# 3557492: done 5011 episodes, mean reward -3.491, speed 120.80 f/s
# 3557898: done 5012 episodes, mean reward -3.489, speed 119.65 f/s
# Test done in 4.29 sec, reward -3.374, steps 768
# 3558898: done 5013 episodes, mean reward -3.484, speed 79.32 f/s
# Test done in 5.16 sec, reward -3.682, steps 915
# 3559898: done 5014 episodes, mean reward -3.487, speed 74.16 f/s
# Test done in 4.02 sec, reward -3.472, steps 716
# 3560898: done 5015 episodes, mean reward -3.492, speed 81.00 f/s
# Test done in 3.66 sec, reward -3.079, steps 650
# 3561898: done 5016 episodes, mean reward -3.503, speed 82.95 f/s
# Test done in 4.58 sec, reward -3.529, steps 799
# 3562422: done 5017 episodes, mean reward -3.506, speed 57.99 f/s
# 3562995: done 5018 episodes, mean reward -3.516, speed 120.12 f/s
# Test done in 5.03 sec, reward -3.903, steps 894
# 3563995: done 5019 episodes, mean reward -3.531, speed 74.57 f/s
# Test done in 4.19 sec, reward -3.592, steps 741
# 3564333: done 5020 episodes, mean reward -3.515, speed 48.08 f/s
# 3564744: done 5021 episodes, mean reward -3.493, speed 119.80 f/s
# Test done in 4.39 sec, reward -3.789, steps 781
# 3565744: done 5022 episodes, mean reward -3.484, speed 78.59 f/s
# Test done in 4.81 sec, reward -3.457, steps 850
# 3566744: done 5023 episodes, mean reward -3.477, speed 76.04 f/s
# Test done in 3.81 sec, reward -3.618, steps 661
# 3567744: done 5024 episodes, mean reward -3.484, speed 80.35 f/s
# Test done in 4.67 sec, reward -3.792, steps 816
# 3568744: done 5025 episodes, mean reward -3.486, speed 76.33 f/s
# Test done in 4.27 sec, reward -3.462, steps 759
# 3569744: done 5026 episodes, mean reward -3.490, speed 79.23 f/s
# Test done in 4.93 sec, reward -3.469, steps 885
# 3570744: done 5027 episodes, mean reward -3.505, speed 75.34 f/s
# Test done in 5.24 sec, reward -3.756, steps 936
# 3571344: done 5028 episodes, mean reward -3.502, speed 58.60 f/s
# Test done in 4.36 sec, reward -3.522, steps 772
# 3572339: done 5029 episodes, mean reward -3.535, speed 78.71 f/s
# 3572731: done 5030 episodes, mean reward -3.541, speed 120.52 f/s
# Test done in 5.19 sec, reward -4.053, steps 928
# 3573149: done 5031 episodes, mean reward -3.529, speed 48.07 f/s
# Test done in 4.58 sec, reward -3.798, steps 814
# 3574149: done 5032 episodes, mean reward -3.507, speed 77.07 f/s
# 3574488: done 5033 episodes, mean reward -3.503, speed 118.07 f/s
# 3574779: done 5034 episodes, mean reward -3.489, speed 118.54 f/s
# Test done in 4.08 sec, reward -3.733, steps 724
# 3575779: done 5035 episodes, mean reward -3.508, speed 80.53 f/s
# Test done in 4.01 sec, reward -3.339, steps 711
# 3576340: done 5036 episodes, mean reward -3.497, speed 64.84 f/s
# Test done in 4.00 sec, reward -3.244, steps 715
# 3577340: done 5037 episodes, mean reward -3.494, speed 81.45 f/s
# Test done in 3.93 sec, reward -3.503, steps 695
# 3578340: done 5038 episodes, mean reward -3.508, speed 81.37 f/s
# Test done in 4.53 sec, reward -3.818, steps 806
# 3579340: done 5039 episodes, mean reward -3.515, speed 77.82 f/s
# 3579830: done 5040 episodes, mean reward -3.525, speed 119.88 f/s
# Test done in 4.57 sec, reward -3.756, steps 813
# 3580830: done 5041 episodes, mean reward -3.543, speed 77.10 f/s
# Test done in 5.41 sec, reward -3.753, steps 957
# 3581193: done 5042 episodes, mean reward -3.543, speed 42.87 f/s
# 3581738: done 5043 episodes, mean reward -3.529, speed 119.65 f/s
# Test done in 4.15 sec, reward -3.666, steps 741
# 3582738: done 5044 episodes, mean reward -3.524, speed 80.18 f/s
# Test done in 3.87 sec, reward -3.337, steps 685
# 3583028: done 5045 episodes, mean reward -3.511, speed 46.07 f/s
# 3583402: done 5046 episodes, mean reward -3.496, speed 119.00 f/s
# 3583940: done 5047 episodes, mean reward -3.482, speed 120.27 f/s
# Test done in 4.15 sec, reward -3.303, steps 737
# 3584853: done 5048 episodes, mean reward -3.492, speed 77.68 f/s
# Test done in 3.79 sec, reward -3.123, steps 675
# 3585197: done 5049 episodes, mean reward -3.496, speed 51.46 f/s
# Test done in 3.97 sec, reward -3.153, steps 704
# 3586197: done 5050 episodes, mean reward -3.489, speed 80.28 f/s
# 3586537: done 5051 episodes, mean reward -3.476, speed 119.44 f/s
# 3586994: done 5052 episodes, mean reward -3.487, speed 119.08 f/s
# Test done in 4.57 sec, reward -3.453, steps 803
# 3587994: done 5053 episodes, mean reward -3.482, speed 77.08 f/s
# Test done in 4.51 sec, reward -3.775, steps 803
# 3588688: done 5054 episodes, mean reward -3.465, speed 67.36 f/s
# Test done in 4.41 sec, reward -3.488, steps 785
# 3589688: done 5055 episodes, mean reward -3.478, speed 78.38 f/s
# Test done in 4.36 sec, reward -3.340, steps 774
# 3590688: done 5056 episodes, mean reward -3.472, speed 78.78 f/s
# Test done in 3.57 sec, reward -2.805, steps 632
# 3591688: done 5057 episodes, mean reward -3.488, speed 82.45 f/s
# Test done in 4.23 sec, reward -3.135, steps 743
# 3592069: done 5058 episodes, mean reward -3.469, speed 50.75 f/s
# 3592418: done 5059 episodes, mean reward -3.450, speed 119.82 f/s
# 3592802: done 5060 episodes, mean reward -3.427, speed 119.20 f/s
# Test done in 3.58 sec, reward -2.607, steps 639
# 3593802: done 5061 episodes, mean reward -3.446, speed 83.18 f/s
# Test done in 4.41 sec, reward -3.554, steps 780
# 3594802: done 5062 episodes, mean reward -3.457, speed 78.18 f/s
# Test done in 4.66 sec, reward -3.648, steps 829
# 3595802: done 5063 episodes, mean reward -3.471, speed 76.87 f/s
# Test done in 4.38 sec, reward -3.168, steps 781
# 3596132: done 5064 episodes, mean reward -3.448, speed 46.17 f/s
# Test done in 4.00 sec, reward -3.090, steps 712
# 3597132: done 5065 episodes, mean reward -3.456, speed 81.24 f/s
# Test done in 4.72 sec, reward -4.104, steps 837
# 3598132: done 5066 episodes, mean reward -3.454, speed 76.45 f/s
# Test done in 3.88 sec, reward -3.313, steps 688
# 3599132: done 5067 episodes, mean reward -3.452, speed 81.78 f/s
# Test done in 4.32 sec, reward -4.017, steps 761
# 3600132: done 5068 episodes, mean reward -3.451, speed 78.66 f/s
# 3600565: done 5069 episodes, mean reward -3.452, speed 119.50 f/s
# Test done in 3.81 sec, reward -3.483, steps 673
# 3601331: done 5070 episodes, mean reward -3.455, speed 75.43 f/s
# 3601707: done 5071 episodes, mean reward -3.454, speed 120.69 f/s
# Test done in 3.59 sec, reward -3.307, steps 634
# 3602097: done 5072 episodes, mean reward -3.425, speed 56.91 f/s
# 3602591: done 5073 episodes, mean reward -3.414, speed 119.69 f/s
# Test done in 3.61 sec, reward -3.501, steps 639
# 3603591: done 5074 episodes, mean reward -3.416, speed 83.70 f/s
# Test done in 3.59 sec, reward -3.322, steps 637
# 3604278: done 5075 episodes, mean reward -3.439, speed 73.66 f/s
# 3604665: done 5076 episodes, mean reward -3.441, speed 120.57 f/s
# Test done in 3.58 sec, reward -3.570, steps 636
# 3605033: done 5077 episodes, mean reward -3.440, speed 55.23 f/s
# 3605388: done 5078 episodes, mean reward -3.436, speed 120.09 f/s
# 3605684: done 5079 episodes, mean reward -3.434, speed 120.42 f/s
# Test done in 4.15 sec, reward -3.816, steps 733
# 3606022: done 5080 episodes, mean reward -3.434, speed 48.47 f/s
# 3606425: done 5081 episodes, mean reward -3.412, speed 119.32 f/s
# Test done in 3.38 sec, reward -3.002, steps 600
# 3607132: done 5082 episodes, mean reward -3.432, speed 75.72 f/s
# Test done in 3.10 sec, reward -2.975, steps 547
# 3608132: done 5083 episodes, mean reward -3.451, speed 87.27 f/s
# Test done in 2.28 sec, reward -2.801, steps 411
# 3609132: done 5084 episodes, mean reward -3.458, speed 94.41 f/s
# 3609874: done 5085 episodes, mean reward -3.469, speed 120.38 f/s
# Test done in 3.34 sec, reward -3.692, steps 597
# 3610208: done 5086 episodes, mean reward -3.457, speed 54.52 f/s
# Test done in 3.65 sec, reward -3.392, steps 643
# 3611020: done 5087 episodes, mean reward -3.465, speed 76.96 f/s
# 3611395: done 5088 episodes, mean reward -3.446, speed 121.09 f/s
# 3611979: done 5089 episodes, mean reward -3.438, speed 120.20 f/s
# Test done in 2.99 sec, reward -3.014, steps 532
# 3612579: done 5090 episodes, mean reward -3.437, speed 75.20 f/s
# 3612876: done 5091 episodes, mean reward -3.406, speed 119.35 f/s
# Test done in 2.89 sec, reward -2.940, steps 511
# 3613246: done 5092 episodes, mean reward -3.388, speed 61.66 f/s
# 3613695: done 5093 episodes, mean reward -3.394, speed 117.92 f/s
# Test done in 2.28 sec, reward -2.793, steps 397
# 3614667: done 5094 episodes, mean reward -3.429, speed 92.64 f/s
# Test done in 3.05 sec, reward -3.168, steps 534
# 3615018: done 5095 episodes, mean reward -3.429, speed 58.36 f/s
# 3615997: done 5096 episodes, mean reward -3.455, speed 120.53 f/s
# Test done in 2.84 sec, reward -2.992, steps 506
# 3616258: done 5097 episodes, mean reward -3.437, speed 52.07 f/s
# Test done in 3.02 sec, reward -3.093, steps 523
# 3617258: done 5098 episodes, mean reward -3.453, speed 87.52 f/s
# 3617512: done 5099 episodes, mean reward -3.458, speed 116.00 f/s
# 3617868: done 5100 episodes, mean reward -3.443, speed 115.24 f/s
# Test done in 3.04 sec, reward -3.248, steps 531
# 3618190: done 5101 episodes, mean reward -3.412, speed 55.61 f/s
# 3618603: done 5102 episodes, mean reward -3.411, speed 120.62 f/s
# 3618891: done 5103 episodes, mean reward -3.394, speed 119.48 f/s
# Test done in 2.70 sec, reward -2.882, steps 480
# 3619304: done 5104 episodes, mean reward -3.390, speed 67.19 f/s
# 3619585: done 5105 episodes, mean reward -3.398, speed 118.19 f/s
# 3619882: done 5106 episodes, mean reward -3.376, speed 118.60 f/s
# Test done in 3.58 sec, reward -3.447, steps 629
# 3620652: done 5107 episodes, mean reward -3.398, speed 76.21 f/s
# Test done in 3.74 sec, reward -3.654, steps 657
# 3621411: done 5108 episodes, mean reward -3.404, speed 75.17 f/s
# 3621789: done 5109 episodes, mean reward -3.390, speed 119.95 f/s
# Test done in 3.71 sec, reward -3.325, steps 657
# 3622047: done 5110 episodes, mean reward -3.388, speed 44.05 f/s
# Test done in 4.24 sec, reward -3.855, steps 749
# 3623047: done 5111 episodes, mean reward -3.407, speed 79.52 f/s
# 3623396: done 5112 episodes, mean reward -3.407, speed 119.52 f/s
# 3623976: done 5113 episodes, mean reward -3.400, speed 120.03 f/s
# Test done in 3.33 sec, reward -2.974, steps 590
# 3624531: done 5114 episodes, mean reward -3.386, speed 69.79 f/s
# 3624965: done 5115 episodes, mean reward -3.364, speed 119.64 f/s
# Test done in 3.70 sec, reward -3.423, steps 652
# 3625800: done 5116 episodes, mean reward -3.374, speed 78.45 f/s
# Test done in 4.39 sec, reward -3.858, steps 780
# 3626362: done 5117 episodes, mean reward -3.376, speed 61.83 f/s
# Test done in 3.17 sec, reward -2.973, steps 548
# 3627362: done 5118 episodes, mean reward -3.385, speed 86.44 f/s
# 3627729: done 5119 episodes, mean reward -3.368, speed 117.87 f/s
# Test done in 3.90 sec, reward -3.331, steps 691
# 3628020: done 5120 episodes, mean reward -3.365, speed 45.90 f/s
# 3628932: done 5121 episodes, mean reward -3.379, speed 119.71 f/s
# Test done in 3.94 sec, reward -3.447, steps 698
# 3629832: done 5122 episodes, mean reward -3.385, speed 78.74 f/s
# Test done in 3.17 sec, reward -2.841, steps 555
# 3630462: done 5123 episodes, mean reward -3.377, speed 74.58 f/s
# 3630857: done 5124 episodes, mean reward -3.359, speed 120.27 f/s
# Test done in 3.69 sec, reward -3.310, steps 649
# 3631141: done 5125 episodes, mean reward -3.339, speed 46.73 f/s
# Test done in 2.98 sec, reward -3.010, steps 528
# 3632141: done 5126 episodes, mean reward -3.341, speed 88.49 f/s
# 3632521: done 5127 episodes, mean reward -3.323, speed 120.15 f/s
# Test done in 3.51 sec, reward -3.002, steps 615
# 3633515: done 5128 episodes, mean reward -3.339, speed 84.17 f/s
# Test done in 3.67 sec, reward -3.295, steps 644
# 3634305: done 5129 episodes, mean reward -3.332, speed 76.46 f/s
# 3634628: done 5130 episodes, mean reward -3.326, speed 119.09 f/s
# 3634961: done 5131 episodes, mean reward -3.326, speed 120.09 f/s
# Test done in 3.44 sec, reward -3.104, steps 611
# 3635295: done 5132 episodes, mean reward -3.313, speed 53.47 f/s
# 3635641: done 5133 episodes, mean reward -3.311, speed 120.38 f/s
# Test done in 3.58 sec, reward -3.113, steps 639
# 3636191: done 5134 episodes, mean reward -3.314, speed 67.26 f/s
# Test done in 2.57 sec, reward -2.597, steps 454
# 3637191: done 5135 episodes, mean reward -3.313, speed 90.59 f/s
# 3637566: done 5136 episodes, mean reward -3.308, speed 120.21 f/s
# Test done in 3.62 sec, reward -3.603, steps 630
# 3638566: done 5137 episodes, mean reward -3.309, speed 83.58 f/s
# Test done in 3.69 sec, reward -3.625, steps 656
# 3639564: done 5138 episodes, mean reward -3.326, speed 83.31 f/s
# Test done in 2.72 sec, reward -2.872, steps 479
# 3640496: done 5139 episodes, mean reward -3.333, speed 89.13 f/s
# 3640856: done 5140 episodes, mean reward -3.329, speed 117.51 f/s
# Test done in 4.52 sec, reward -3.656, steps 793
# 3641856: done 5141 episodes, mean reward -3.324, speed 77.65 f/s
# Test done in 3.42 sec, reward -3.508, steps 610
# 3642728: done 5142 episodes, mean reward -3.348, speed 81.70 f/s
# Test done in 4.25 sec, reward -3.540, steps 755
# 3643295: done 5143 episodes, mean reward -3.349, speed 62.11 f/s
# Test done in 4.15 sec, reward -3.892, steps 727
# 3644295: done 5144 episodes, mean reward -3.350, speed 78.48 f/s
# Test done in 3.48 sec, reward -3.402, steps 619
# 3645234: done 5145 episodes, mean reward -3.382, speed 83.20 f/s
# Test done in 4.87 sec, reward -4.046, steps 868
# 3646049: done 5146 episodes, mean reward -3.400, speed 69.95 f/s
# 3646347: done 5147 episodes, mean reward -3.390, speed 120.41 f/s
# Test done in 3.71 sec, reward -3.298, steps 653
# 3647347: done 5148 episodes, mean reward -3.385, speed 83.02 f/s
# Test done in 4.65 sec, reward -4.319, steps 820
# 3648065: done 5149 episodes, mean reward -3.403, speed 67.10 f/s
# 3648804: done 5150 episodes, mean reward -3.401, speed 119.25 f/s
# Test done in 4.39 sec, reward -3.944, steps 785
# 3649699: done 5151 episodes, mean reward -3.421, speed 75.65 f/s
# Test done in 4.48 sec, reward -3.912, steps 791
# 3650005: done 5152 episodes, mean reward -3.412, speed 43.63 f/s
# 3650387: done 5153 episodes, mean reward -3.398, speed 119.79 f/s
# Test done in 4.08 sec, reward -3.615, steps 722
# 3651387: done 5154 episodes, mean reward -3.405, speed 80.74 f/s
# Test done in 4.12 sec, reward -3.634, steps 733
# 3652170: done 5155 episodes, mean reward -3.414, speed 73.59 f/s
# 3652990: done 5156 episodes, mean reward -3.422, speed 119.16 f/s
# Test done in 4.74 sec, reward -3.379, steps 840
# 3653350: done 5157 episodes, mean reward -3.407, speed 46.18 f/s
# Test done in 3.33 sec, reward -3.249, steps 582
# 3654241: done 5158 episodes, mean reward -3.437, speed 81.96 f/s
# Test done in 4.29 sec, reward -3.619, steps 754
# 3655241: done 5159 episodes, mean reward -3.449, speed 79.30 f/s
# Test done in 4.70 sec, reward -3.912, steps 829
# 3656228: done 5160 episodes, mean reward -3.486, speed 76.40 f/s
# 3656980: done 5161 episodes, mean reward -3.493, speed 119.85 f/s
# Test done in 3.92 sec, reward -3.926, steps 699
# 3657856: done 5162 episodes, mean reward -3.509, speed 78.02 f/s
# Test done in 4.08 sec, reward -3.539, steps 725
# 3658628: done 5163 episodes, mean reward -3.515, speed 73.32 f/s
# Test done in 3.80 sec, reward -3.600, steps 675
# 3659008: done 5164 episodes, mean reward -3.524, speed 54.54 f/s
# 3659740: done 5165 episodes, mean reward -3.531, speed 120.43 f/s
# Test done in 3.86 sec, reward -3.974, steps 677
# 3660054: done 5166 episodes, mean reward -3.514, speed 48.28 f/s
# 3660368: done 5167 episodes, mean reward -3.498, speed 117.40 f/s
# 3660976: done 5168 episodes, mean reward -3.490, speed 118.62 f/s
# Test done in 3.66 sec, reward -3.545, steps 641
# 3661758: done 5169 episodes, mean reward -3.512, speed 76.08 f/s
# Test done in 3.85 sec, reward -4.013, steps 681
# 3662532: done 5170 episodes, mean reward -3.504, speed 75.09 f/s
# 3662979: done 5171 episodes, mean reward -3.514, speed 119.50 f/s
# Test done in 4.16 sec, reward -3.945, steps 742
# 3663382: done 5172 episodes, mean reward -3.514, speed 53.51 f/s
# 3663968: done 5173 episodes, mean reward -3.522, speed 119.76 f/s
# Test done in 4.10 sec, reward -3.718, steps 721
# 3664628: done 5174 episodes, mean reward -3.520, speed 68.91 f/s
# Test done in 4.00 sec, reward -4.038, steps 714
# 3665417: done 5175 episodes, mean reward -3.515, speed 74.35 f/s
# 3665864: done 5176 episodes, mean reward -3.520, speed 119.54 f/s
# Test done in 3.81 sec, reward -3.847, steps 674
# 3666864: done 5177 episodes, mean reward -3.542, speed 81.73 f/s
# Test done in 3.96 sec, reward -3.778, steps 699
# 3667864: done 5178 episodes, mean reward -3.555, speed 81.04 f/s
# Test done in 4.10 sec, reward -3.552, steps 718
# 3668708: done 5179 episodes, mean reward -3.583, speed 74.27 f/s
# Test done in 4.03 sec, reward -3.883, steps 710
# 3669510: done 5180 episodes, mean reward -3.610, speed 74.07 f/s
# Test done in 4.41 sec, reward -3.786, steps 784
# 3670359: done 5181 episodes, mean reward -3.637, speed 73.80 f/s
# 3670775: done 5182 episodes, mean reward -3.620, speed 119.59 f/s
# Test done in 4.86 sec, reward -4.203, steps 854
# 3671253: done 5183 episodes, mean reward -3.606, speed 54.22 f/s
# 3671596: done 5184 episodes, mean reward -3.577, speed 120.16 f/s
# Test done in 3.71 sec, reward -3.595, steps 653
# 3672596: done 5185 episodes, mean reward -3.577, speed 82.93 f/s
# Test done in 3.62 sec, reward -3.708, steps 638
# 3673596: done 5186 episodes, mean reward -3.590, speed 82.87 f/s
# Test done in 4.32 sec, reward -3.993, steps 771
# 3674596: done 5187 episodes, mean reward -3.580, speed 78.97 f/s
# Test done in 5.13 sec, reward -3.841, steps 914
# 3675596: done 5188 episodes, mean reward -3.593, speed 74.34 f/s
# Test done in 4.48 sec, reward -4.145, steps 796
# 3676596: done 5189 episodes, mean reward -3.597, speed 78.23 f/s
# 3677000: done 5190 episodes, mean reward -3.589, speed 119.34 f/s
# Test done in 3.84 sec, reward -3.987, steps 680
# 3678000: done 5191 episodes, mean reward -3.609, speed 81.98 f/s
# Test done in 4.29 sec, reward -4.402, steps 761
# 3678335: done 5192 episodes, mean reward -3.605, speed 47.24 f/s
# Test done in 4.54 sec, reward -3.980, steps 798
# 3679215: done 5193 episodes, mean reward -3.630, speed 73.80 f/s
# 3679994: done 5194 episodes, mean reward -3.621, speed 118.52 f/s
# Test done in 4.18 sec, reward -3.974, steps 748
# 3680566: done 5195 episodes, mean reward -3.638, speed 63.69 f/s
# 3680935: done 5196 episodes, mean reward -3.612, speed 120.14 f/s
# Test done in 4.35 sec, reward -3.674, steps 770
# 3681935: done 5197 episodes, mean reward -3.631, speed 78.79 f/s
# Test done in 3.81 sec, reward -3.769, steps 673
# 3682935: done 5198 episodes, mean reward -3.628, speed 82.55 f/s
# Test done in 4.34 sec, reward -4.224, steps 770
# 3683935: done 5199 episodes, mean reward -3.644, speed 78.65 f/s
# Test done in 3.78 sec, reward -3.646, steps 673
# 3684300: done 5200 episodes, mean reward -3.642, speed 53.38 f/s
# 3684716: done 5201 episodes, mean reward -3.639, speed 119.80 f/s
# Test done in 4.65 sec, reward -3.945, steps 837
# 3685110: done 5202 episodes, mean reward -3.636, speed 49.44 f/s
# 3685436: done 5203 episodes, mean reward -3.639, speed 117.73 f/s
# Test done in 3.50 sec, reward -3.870, steps 613
# 3686436: done 5204 episodes, mean reward -3.657, speed 83.09 f/s
# Test done in 3.69 sec, reward -3.919, steps 655
# 3687436: done 5205 episodes, mean reward -3.672, speed 82.99 f/s
# 3687781: done 5206 episodes, mean reward -3.668, speed 120.21 f/s
# Test done in 4.11 sec, reward -3.817, steps 733
# 3688596: done 5207 episodes, mean reward -3.671, speed 74.74 f/s
# Test done in 4.18 sec, reward -4.152, steps 743
# 3689596: done 5208 episodes, mean reward -3.670, speed 79.94 f/s
# Test done in 4.67 sec, reward -3.813, steps 835
# 3690433: done 5209 episodes, mean reward -3.694, speed 71.83 f/s
# Test done in 4.77 sec, reward -4.206, steps 843
# 3691029: done 5210 episodes, mean reward -3.705, speed 61.31 f/s
# Test done in 4.48 sec, reward -3.820, steps 791
# 3692029: done 5211 episodes, mean reward -3.703, speed 77.91 f/s
# Test done in 4.76 sec, reward -4.030, steps 835
# 3693029: done 5212 episodes, mean reward -3.716, speed 75.20 f/s
# 3693879: done 5213 episodes, mean reward -3.743, speed 117.33 f/s
# Test done in 4.69 sec, reward -4.301, steps 834
# 3694787: done 5214 episodes, mean reward -3.765, speed 74.23 f/s
# Test done in 4.30 sec, reward -3.864, steps 770
# 3695787: done 5215 episodes, mean reward -3.780, speed 79.14 f/s
# Test done in 5.61 sec, reward -3.869, steps 998
# 3696787: done 5216 episodes, mean reward -3.770, speed 71.67 f/s
# Test done in 4.81 sec, reward -3.906, steps 857
# 3697787: done 5217 episodes, mean reward -3.779, speed 76.17 f/s
# Test done in 5.59 sec, reward -4.273, steps 981
# 3698224: done 5218 episodes, mean reward -3.762, speed 47.27 f/s
# Test done in 4.80 sec, reward -3.933, steps 856
# 3699224: done 5219 episodes, mean reward -3.779, speed 75.66 f/s
# Test done in 4.75 sec, reward -3.938, steps 845
# 3700224: done 5220 episodes, mean reward -3.801, speed 76.47 f/s
# 3700636: done 5221 episodes, mean reward -3.778, speed 119.48 f/s
# Test done in 4.95 sec, reward -4.072, steps 878
# 3701091: done 5222 episodes, mean reward -3.753, speed 52.18 f/s
# 3701488: done 5223 episodes, mean reward -3.749, speed 119.96 f/s
# 3701859: done 5224 episodes, mean reward -3.750, speed 119.83 f/s
# Test done in 4.84 sec, reward -3.874, steps 867
# 3702243: done 5225 episodes, mean reward -3.748, speed 47.86 f/s
# Test done in 5.19 sec, reward -4.393, steps 928
# 3703243: done 5226 episodes, mean reward -3.739, speed 74.02 f/s
# Test done in 5.00 sec, reward -4.356, steps 889
# 3704208: done 5227 episodes, mean reward -3.769, speed 73.71 f/s
# Test done in 4.75 sec, reward -3.735, steps 846
# 3705208: done 5228 episodes, mean reward -3.757, speed 75.99 f/s
# 3705972: done 5229 episodes, mean reward -3.752, speed 119.90 f/s
# Test done in 5.44 sec, reward -3.940, steps 963
# 3706385: done 5230 episodes, mean reward -3.761, speed 46.52 f/s
# Test done in 4.83 sec, reward -3.671, steps 858
# 3707385: done 5231 episodes, mean reward -3.777, speed 76.02 f/s
# Test done in 5.13 sec, reward -3.988, steps 913
# 3708385: done 5232 episodes, mean reward -3.791, speed 74.51 f/s
# Test done in 5.21 sec, reward -4.287, steps 920
# 3709346: done 5233 episodes, mean reward -3.815, speed 72.42 f/s
# 3709834: done 5234 episodes, mean reward -3.812, speed 120.00 f/s
# Test done in 4.75 sec, reward -3.819, steps 839
# 3710834: done 5235 episodes, mean reward -3.810, speed 75.74 f/s
# Test done in 5.16 sec, reward -3.972, steps 917
# 3711834: done 5236 episodes, mean reward -3.820, speed 74.02 f/s
# Test done in 4.72 sec, reward -3.688, steps 839
# 3712834: done 5237 episodes, mean reward -3.816, speed 76.57 f/s
# Test done in 4.31 sec, reward -3.554, steps 765
# 3713834: done 5238 episodes, mean reward -3.798, speed 79.04 f/s
# Test done in 4.16 sec, reward -3.614, steps 738
# 3714834: done 5239 episodes, mean reward -3.785, speed 79.65 f/s
# Test done in 4.26 sec, reward -3.643, steps 754
# 3715834: done 5240 episodes, mean reward -3.801, speed 79.26 f/s
# Test done in 4.62 sec, reward -3.524, steps 817
# 3716834: done 5241 episodes, mean reward -3.801, speed 75.12 f/s
# Test done in 4.93 sec, reward -3.802, steps 874
# 3717472: done 5242 episodes, mean reward -3.790, speed 61.90 f/s
# 3717828: done 5243 episodes, mean reward -3.782, speed 120.54 f/s
# Test done in 5.19 sec, reward -3.928, steps 925
# 3718828: done 5244 episodes, mean reward -3.778, speed 74.09 f/s
# Test done in 5.17 sec, reward -3.946, steps 917
# 3719828: done 5245 episodes, mean reward -3.759, speed 73.97 f/s
# Test done in 3.93 sec, reward -3.273, steps 697
# 3720828: done 5246 episodes, mean reward -3.751, speed 81.68 f/s
# Test done in 5.15 sec, reward -3.719, steps 913
# 3721228: done 5247 episodes, mean reward -3.759, speed 47.11 f/s
# 3721638: done 5248 episodes, mean reward -3.739, speed 119.52 f/s
# Test done in 4.41 sec, reward -3.186, steps 778
# 3722638: done 5249 episodes, mean reward -3.731, speed 78.41 f/s
# Test done in 4.59 sec, reward -3.245, steps 811
# 3723638: done 5250 episodes, mean reward -3.723, speed 77.23 f/s
# 3723973: done 5251 episodes, mean reward -3.704, speed 119.41 f/s
# Test done in 5.63 sec, reward -3.420, steps 1000
# 3724973: done 5252 episodes, mean reward -3.714, speed 71.57 f/s
# Test done in 5.20 sec, reward -3.456, steps 928
# 3725973: done 5253 episodes, mean reward -3.726, speed 73.84 f/s
# Test done in 3.62 sec, reward -2.898, steps 643
# 3726260: done 5254 episodes, mean reward -3.710, speed 47.79 f/s
# 3726704: done 5255 episodes, mean reward -3.688, speed 120.18 f/s
# Test done in 4.21 sec, reward -3.278, steps 749
# 3727704: done 5256 episodes, mean reward -3.678, speed 79.72 f/s
# 3727988: done 5257 episodes, mean reward -3.677, speed 119.10 f/s
# Test done in 4.51 sec, reward -3.176, steps 798
# 3728278: done 5258 episodes, mean reward -3.649, speed 41.82 f/s
# Test done in 4.34 sec, reward -3.160, steps 759
# 3729278: done 5259 episodes, mean reward -3.645, speed 78.11 f/s
# Test done in 4.34 sec, reward -3.165, steps 771
# 3730278: done 5260 episodes, mean reward -3.630, speed 78.99 f/s
# Test done in 5.22 sec, reward -3.453, steps 935
# 3731278: done 5261 episodes, mean reward -3.621, speed 73.82 f/s
# 3731625: done 5262 episodes, mean reward -3.590, speed 120.68 f/s
# 3731956: done 5263 episodes, mean reward -3.568, speed 119.90 f/s
# Test done in 4.91 sec, reward -3.506, steps 867
# 3732249: done 5264 episodes, mean reward -3.567, speed 39.61 f/s
# Test done in 4.20 sec, reward -3.199, steps 746
# 3733249: done 5265 episodes, mean reward -3.558, speed 79.51 f/s
# Test done in 4.50 sec, reward -3.208, steps 808
# 3734249: done 5266 episodes, mean reward -3.578, speed 78.08 f/s
# Test done in 4.61 sec, reward -3.413, steps 812
# 3735249: done 5267 episodes, mean reward -3.591, speed 76.94 f/s
# 3735582: done 5268 episodes, mean reward -3.582, speed 118.74 f/s
# Test done in 4.62 sec, reward -3.571, steps 819
# 3736582: done 5269 episodes, mean reward -3.576, speed 77.09 f/s
# 3736960: done 5270 episodes, mean reward -3.556, speed 119.40 f/s
# Test done in 4.18 sec, reward -3.500, steps 745
# 3737960: done 5271 episodes, mean reward -3.570, speed 79.82 f/s
# Test done in 5.33 sec, reward -3.983, steps 947
# 3738250: done 5272 episodes, mean reward -3.565, speed 37.47 f/s
# Test done in 4.26 sec, reward -3.384, steps 756
# 3739250: done 5273 episodes, mean reward -3.575, speed 79.55 f/s
# 3739574: done 5274 episodes, mean reward -3.557, speed 120.29 f/s
# Test done in 4.75 sec, reward -3.403, steps 835
# 3740165: done 5275 episodes, mean reward -3.545, speed 60.66 f/s
# 3740546: done 5276 episodes, mean reward -3.542, speed 115.45 f/s
# Test done in 4.75 sec, reward -3.499, steps 835
# 3741546: done 5277 episodes, mean reward -3.541, speed 75.25 f/s
# 3741834: done 5278 episodes, mean reward -3.528, speed 118.22 f/s
# Test done in 4.19 sec, reward -3.224, steps 748
# 3742284: done 5279 episodes, mean reward -3.510, speed 56.75 f/s
# Test done in 4.65 sec, reward -3.469, steps 829
# 3743284: done 5280 episodes, mean reward -3.501, speed 76.89 f/s
# 3743758: done 5281 episodes, mean reward -3.484, speed 121.00 f/s
# Test done in 3.55 sec, reward -3.251, steps 631
# 3744278: done 5282 episodes, mean reward -3.487, speed 65.94 f/s
# Test done in 4.53 sec, reward -3.285, steps 811
# 3745278: done 5283 episodes, mean reward -3.499, speed 77.84 f/s
# 3745715: done 5284 episodes, mean reward -3.503, speed 119.61 f/s
# Test done in 3.99 sec, reward -3.738, steps 713
# 3746227: done 5285 episodes, mean reward -3.498, speed 62.04 f/s
# Test done in 3.62 sec, reward -3.545, steps 646
# 3747227: done 5286 episodes, mean reward -3.500, speed 83.33 f/s
# Test done in 3.90 sec, reward -3.425, steps 691
# 3748117: done 5287 episodes, mean reward -3.508, speed 77.81 f/s
# Test done in 4.85 sec, reward -4.679, steps 859
# 3749068: done 5288 episodes, mean reward -3.523, speed 74.49 f/s
# Test done in 4.89 sec, reward -3.972, steps 870
# 3750068: done 5289 episodes, mean reward -3.524, speed 75.78 f/s
# Test done in 5.29 sec, reward -3.949, steps 942
# 3751068: done 5290 episodes, mean reward -3.550, speed 73.49 f/s
# 3751453: done 5291 episodes, mean reward -3.527, speed 119.92 f/s
# Test done in 4.90 sec, reward -3.803, steps 868
# 3752453: done 5292 episodes, mean reward -3.549, speed 75.67 f/s
# 3752784: done 5293 episodes, mean reward -3.517, speed 121.09 f/s
# Test done in 5.24 sec, reward -3.982, steps 937
# 3753320: done 5294 episodes, mean reward -3.499, speed 55.10 f/s
# 3753676: done 5295 episodes, mean reward -3.480, speed 119.49 f/s
# Test done in 3.83 sec, reward -3.162, steps 672
# 3754119: done 5296 episodes, mean reward -3.475, speed 58.53 f/s
# Test done in 5.04 sec, reward -3.772, steps 901
# 3755119: done 5297 episodes, mean reward -3.473, speed 74.81 f/s
# Test done in 4.46 sec, reward -3.503, steps 788
# 3756119: done 5298 episodes, mean reward -3.474, speed 78.13 f/s
# 3756596: done 5299 episodes, mean reward -3.456, speed 120.07 f/s
# Test done in 4.72 sec, reward -3.789, steps 837
# 3757016: done 5300 episodes, mean reward -3.458, speed 50.91 f/s
# Test done in 4.72 sec, reward -3.308, steps 840
# 3758016: done 5301 episodes, mean reward -3.479, speed 76.70 f/s
# 3758353: done 5302 episodes, mean reward -3.482, speed 120.23 f/s
# 3758643: done 5303 episodes, mean reward -3.479, speed 119.75 f/s
# Test done in 4.40 sec, reward -3.392, steps 787
# 3759084: done 5304 episodes, mean reward -3.463, speed 54.58 f/s
# Test done in 4.75 sec, reward -3.480, steps 842
# 3760084: done 5305 episodes, mean reward -3.461, speed 76.34 f/s
# Test done in 4.68 sec, reward -3.659, steps 835
# 3761084: done 5306 episodes, mean reward -3.483, speed 77.02 f/s
# 3761545: done 5307 episodes, mean reward -3.459, speed 119.69 f/s
# Test done in 4.33 sec, reward -3.704, steps 769
# 3762258: done 5308 episodes, mean reward -3.451, speed 69.43 f/s
# 3762754: done 5309 episodes, mean reward -3.427, speed 120.02 f/s
# Test done in 3.50 sec, reward -2.911, steps 621
# 3763754: done 5310 episodes, mean reward -3.431, speed 84.58 f/s
# Test done in 4.41 sec, reward -3.395, steps 781
# 3764350: done 5311 episodes, mean reward -3.422, speed 62.84 f/s
# 3764634: done 5312 episodes, mean reward -3.408, speed 115.60 f/s
# Test done in 4.20 sec, reward -3.259, steps 736
# 3765086: done 5313 episodes, mean reward -3.374, speed 56.04 f/s
# 3765632: done 5314 episodes, mean reward -3.352, speed 120.24 f/s
# Test done in 4.45 sec, reward -3.158, steps 783
# 3766632: done 5315 episodes, mean reward -3.355, speed 77.90 f/s
# Test done in 4.19 sec, reward -3.226, steps 749
# 3767023: done 5316 episodes, mean reward -3.336, speed 52.21 f/s
# 3767455: done 5317 episodes, mean reward -3.319, speed 119.93 f/s
# 3767843: done 5318 episodes, mean reward -3.310, speed 120.73 f/s
# Test done in 5.28 sec, reward -3.722, steps 940
# ...
# Test done in 3.03 sec, reward -2.622, steps 515
# 5370450: done 7620 episodes, mean reward -3.237, speed 70.55 f/s
# 5370812: done 7621 episodes, mean reward -3.242, speed 113.36 f/s
# Test done in 4.11 sec, reward -3.270, steps 686
# 5371449: done 7622 episodes, mean reward -3.241, speed 64.92 f/s
# 5371715: done 7623 episodes, mean reward -3.223, speed 107.69 f/s
# Test done in 3.53 sec, reward -2.762, steps 556
# 5372140: done 7624 episodes, mean reward -3.236, speed 56.11 f/s
# Test done in 3.94 sec, reward -3.237, steps 626
# 5373070: done 7625 episodes, mean reward -3.268, speed 72.80 f/s
# 5373445: done 7626 episodes, mean reward -3.241, speed 105.51 f/s
# Test done in 4.14 sec, reward -3.058, steps 657
# 5374417: done 7627 episodes, mean reward -3.241, speed 72.89 f/s
# 5374801: done 7628 episodes, mean reward -3.218, speed 110.02 f/s
# Test done in 4.13 sec, reward -3.298, steps 660
# 5375046: done 7629 episodes, mean reward -3.204, speed 37.88 f/s
# Test done in 3.96 sec, reward -2.968, steps 621
# 5376046: done 7630 episodes, mean reward -3.205, speed 74.13 f/s
# 5376704: done 7631 episodes, mean reward -3.221, speed 104.72 f/s
# 5376931: done 7632 episodes, mean reward -3.218, speed 105.32 f/s
# Test done in 3.59 sec, reward -3.040, steps 567
# 5377931: done 7633 episodes, mean reward -3.219, speed 78.88 f/s
# Test done in 4.12 sec, reward -3.494, steps 677
# 5378931: done 7634 episodes, mean reward -3.240, speed 76.59 f/s
# Test done in 3.74 sec, reward -3.072, steps 617
# 5379704: done 7635 episodes, mean reward -3.238, speed 72.31 f/s
# Test done in 4.53 sec, reward -3.607, steps 739
# 5380704: done 7636 episodes, mean reward -3.232, speed 73.59 f/s
# Test done in 3.80 sec, reward -3.389, steps 630
# 5381371: done 7637 episodes, mean reward -3.250, speed 68.22 f/s
# Test done in 4.85 sec, reward -4.006, steps 802
# 5382240: done 7638 episodes, mean reward -3.253, speed 68.69 f/s
# 5382507: done 7639 episodes, mean reward -3.253, speed 110.70 f/s
# 5382818: done 7640 episodes, mean reward -3.260, speed 111.06 f/s
# Test done in 4.38 sec, reward -3.845, steps 724
# 5383190: done 7641 episodes, mean reward -3.245, speed 48.20 f/s
# Test done in 4.09 sec, reward -3.031, steps 673
# 5384190: done 7642 episodes, mean reward -3.248, speed 76.84 f/s
# 5384443: done 7643 episodes, mean reward -3.235, speed 112.10 f/s
# 5384870: done 7644 episodes, mean reward -3.213, speed 111.52 f/s
# Test done in 3.62 sec, reward -2.918, steps 597
# 5385214: done 7645 episodes, mean reward -3.195, speed 51.24 f/s
# 5385591: done 7646 episodes, mean reward -3.198, speed 111.38 f/s
# 5385926: done 7647 episodes, mean reward -3.201, speed 112.29 f/s
# Test done in 4.53 sec, reward -3.659, steps 745
# 5386926: done 7648 episodes, mean reward -3.207, speed 73.34 f/s
# Test done in 5.01 sec, reward -4.018, steps 818
# 5387926: done 7649 episodes, mean reward -3.219, speed 71.41 f/s
# Test done in 3.83 sec, reward -2.940, steps 637
# 5388267: done 7650 episodes, mean reward -3.199, speed 49.58 f/s
# 5388693: done 7651 episodes, mean reward -3.179, speed 112.00 f/s
# Test done in 4.69 sec, reward -3.839, steps 766
# 5389143: done 7652 episodes, mean reward -3.178, speed 51.03 f/s
# 5389566: done 7653 episodes, mean reward -3.181, speed 107.55 f/s
# Test done in 3.54 sec, reward -2.631, steps 589
# 5390054: done 7654 episodes, mean reward -3.181, speed 61.56 f/s
# Test done in 3.80 sec, reward -3.540, steps 632
# 5391054: done 7655 episodes, mean reward -3.199, speed 78.45 f/s
# 5391394: done 7656 episodes, mean reward -3.181, speed 110.93 f/s
# Test done in 4.63 sec, reward -3.861, steps 761
# 5392141: done 7657 episodes, mean reward -3.200, speed 65.73 f/s
# 5392443: done 7658 episodes, mean reward -3.195, speed 109.82 f/s
# Test done in 4.69 sec, reward -3.565, steps 779
# 5393337: done 7659 episodes, mean reward -3.188, speed 70.08 f/s
# Test done in 3.25 sec, reward -2.975, steps 538
# 5394122: done 7660 episodes, mean reward -3.213, speed 76.72 f/s
# 5394445: done 7661 episodes, mean reward -3.177, speed 110.77 f/s
# Test done in 5.14 sec, reward -3.633, steps 854
# 5395445: done 7662 episodes, mean reward -3.200, speed 70.63 f/s
# 5395787: done 7663 episodes, mean reward -3.176, speed 110.80 f/s
# Test done in 4.40 sec, reward -3.312, steps 730
# 5396787: done 7664 episodes, mean reward -3.191, speed 74.51 f/s
# Test done in 3.34 sec, reward -3.057, steps 552
# 5397576: done 7665 episodes, mean reward -3.187, speed 75.52 f/s
# Test done in 3.64 sec, reward -3.100, steps 603
# 5398576: done 7666 episodes, mean reward -3.202, speed 78.76 f/s
# Test done in 3.83 sec, reward -3.033, steps 622
# 5399507: done 7667 episodes, mean reward -3.230, speed 75.54 f/s
# Test done in 3.22 sec, reward -2.950, steps 536
# 5400507: done 7668 episodes, mean reward -3.235, speed 81.46 f/s
# 5400854: done 7669 episodes, mean reward -3.232, speed 111.64 f/s
# Test done in 2.94 sec, reward -2.773, steps 484
# 5401227: done 7670 episodes, mean reward -3.234, speed 59.37 f/s
# Test done in 3.92 sec, reward -3.265, steps 646
# 5402167: done 7671 episodes, mean reward -3.245, speed 74.92 f/s
# 5402610: done 7672 episodes, mean reward -3.241, speed 112.13 f/s
# Test done in 4.00 sec, reward -3.458, steps 663
# 5403219: done 7673 episodes, mean reward -3.243, speed 64.20 f/s
# 5403751: done 7674 episodes, mean reward -3.233, speed 111.29 f/s
# Test done in 2.70 sec, reward -2.867, steps 452
# 5404565: done 7675 episodes, mean reward -3.236, speed 81.10 f/s
# Test done in 4.04 sec, reward -3.135, steps 665
# 5405103: done 7676 episodes, mean reward -3.215, speed 60.27 f/s
# 5405520: done 7677 episodes, mean reward -3.215, speed 110.64 f/s
# 5405956: done 7678 episodes, mean reward -3.214, speed 111.59 f/s
# Test done in 3.84 sec, reward -3.150, steps 644
# 5406939: done 7679 episodes, mean reward -3.246, speed 77.84 f/s
# Test done in 3.32 sec, reward -3.055, steps 540
# 5407353: done 7680 episodes, mean reward -3.248, speed 58.93 f/s
# Test done in 3.49 sec, reward -3.183, steps 580
# 5408353: done 7681 episodes, mean reward -3.252, speed 80.18 f/s
# 5408631: done 7682 episodes, mean reward -3.253, speed 111.97 f/s
# Test done in 3.28 sec, reward -3.224, steps 546
# 5409017: done 7683 episodes, mean reward -3.257, speed 57.52 f/s
# 5409522: done 7684 episodes, mean reward -3.237, speed 110.99 f/s
# 5409871: done 7685 episodes, mean reward -3.238, speed 111.21 f/s
# Test done in 3.01 sec, reward -3.077, steps 503
# 5410871: done 7686 episodes, mean reward -3.236, speed 83.22 f/s
# Test done in 3.85 sec, reward -3.298, steps 638
# 5411871: done 7687 episodes, mean reward -3.254, speed 77.28 f/s
# Test done in 3.58 sec, reward -3.110, steps 592
# 5412828: done 7688 episodes, mean reward -3.284, speed 78.67 f/s
# Test done in 3.65 sec, reward -3.131, steps 609
# 5413145: done 7689 episodes, mean reward -3.285, speed 48.36 f/s
# Test done in 2.91 sec, reward -2.699, steps 483
# 5414145: done 7690 episodes, mean reward -3.296, speed 82.35 f/s
# 5414453: done 7691 episodes, mean reward -3.274, speed 111.08 f/s
# 5414825: done 7692 episodes, mean reward -3.259, speed 110.74 f/s
# Test done in 3.95 sec, reward -3.355, steps 650
# 5415775: done 7693 episodes, mean reward -3.291, speed 76.37 f/s
# Test done in 3.46 sec, reward -2.913, steps 574
# 5416775: done 7694 episodes, mean reward -3.308, speed 80.41 f/s
# Test done in 3.02 sec, reward -3.052, steps 500
# 5417775: done 7695 episodes, mean reward -3.323, speed 83.36 f/s
# Test done in 2.61 sec, reward -2.714, steps 431
# 5418103: done 7696 episodes, mean reward -3.305, speed 58.66 f/s
# 5418508: done 7697 episodes, mean reward -3.306, speed 110.51 f/s
# Test done in 3.24 sec, reward -3.062, steps 535
# 5419246: done 7698 episodes, mean reward -3.321, speed 74.76 f/s
# Test done in 3.48 sec, reward -2.927, steps 579
# 5420170: done 7699 episodes, mean reward -3.344, speed 78.26 f/s
# Test done in 3.92 sec, reward -3.646, steps 650
# 5421170: done 7700 episodes, mean reward -3.364, speed 77.52 f/s
# Test done in 3.15 sec, reward -3.115, steps 519
# 5422170: done 7701 episodes, mean reward -3.364, speed 82.77 f/s
# 5422486: done 7702 episodes, mean reward -3.370, speed 110.37 f/s
# Test done in 3.37 sec, reward -2.926, steps 556
# 5423486: done 7703 episodes, mean reward -3.384, speed 81.08 f/s
# Test done in 3.33 sec, reward -3.257, steps 550
# 5424486: done 7704 episodes, mean reward -3.401, speed 80.85 f/s
# Test done in 3.57 sec, reward -3.405, steps 590
# 5425486: done 7705 episodes, mean reward -3.401, speed 79.37 f/s
# 5425799: done 7706 episodes, mean reward -3.390, speed 111.29 f/s
# Test done in 2.71 sec, reward -2.900, steps 449
# 5426799: done 7707 episodes, mean reward -3.379, speed 85.98 f/s
# Test done in 3.48 sec, reward -3.532, steps 578
# 5427799: done 7708 episodes, mean reward -3.376, speed 80.38 f/s
# Test done in 3.68 sec, reward -3.391, steps 615
# 5428799: done 7709 episodes, mean reward -3.386, speed 79.11 f/s
# Test done in 3.38 sec, reward -2.960, steps 568
# 5429512: done 7710 episodes, mean reward -3.400, speed 72.92 f/s
# 5429813: done 7711 episodes, mean reward -3.402, speed 110.09 f/s
# Test done in 3.27 sec, reward -3.113, steps 540
# 5430263: done 7712 episodes, mean reward -3.384, speed 61.49 f/s
# 5430659: done 7713 episodes, mean reward -3.387, speed 112.18 f/s
# Test done in 2.90 sec, reward -3.287, steps 483
# 5431517: done 7714 episodes, mean reward -3.394, speed 80.47 f/s
# Test done in 4.46 sec, reward -3.577, steps 736
# 5432060: done 7715 episodes, mean reward -3.399, speed 58.29 f/s
# 5432426: done 7716 episodes, mean reward -3.384, speed 112.42 f/s
# Test done in 3.90 sec, reward -3.447, steps 650
# 5433059: done 7717 episodes, mean reward -3.382, speed 66.17 f/s
# 5433471: done 7718 episodes, mean reward -3.383, speed 111.31 f/s
# 5433873: done 7719 episodes, mean reward -3.385, speed 112.01 f/s
# Test done in 3.06 sec, reward -3.232, steps 515
# 5434275: done 7720 episodes, mean reward -3.374, speed 60.44 f/s
# 5434681: done 7721 episodes, mean reward -3.368, speed 110.32 f/s
# Test done in 2.37 sec, reward -2.404, steps 395
# 5435609: done 7722 episodes, mean reward -3.391, speed 86.78 f/s
# Test done in 3.78 sec, reward -3.204, steps 626
# 5436121: done 7723 episodes, mean reward -3.395, speed 61.14 f/s
# 5436678: done 7724 episodes, mean reward -3.406, speed 111.41 f/s
# Test done in 2.90 sec, reward -2.789, steps 479
# 5437432: done 7725 episodes, mean reward -3.395, speed 77.70 f/s
# Test done in 4.02 sec, reward -3.543, steps 669
# 5438432: done 7726 episodes, mean reward -3.412, speed 76.29 f/s
# Test done in 3.94 sec, reward -3.353, steps 650
# 5439190: done 7727 episodes, mean reward -3.406, speed 69.28 f/s
# Test done in 3.95 sec, reward -3.496, steps 657
# 5440076: done 7728 episodes, mean reward -3.434, speed 74.48 f/s
# 5440584: done 7729 episodes, mean reward -3.436, speed 110.83 f/s
# 5440860: done 7730 episodes, mean reward -3.415, speed 111.17 f/s
# Test done in 4.73 sec, reward -3.523, steps 782
# 5441336: done 7731 episodes, mean reward -3.418, speed 52.99 f/s
# 5441596: done 7732 episodes, mean reward -3.418, speed 112.42 f/s
# Test done in 4.44 sec, reward -3.371, steps 745
# 5442451: done 7733 episodes, mean reward -3.427, speed 70.58 f/s
# Test done in 3.65 sec, reward -2.981, steps 607
# 5443356: done 7734 episodes, mean reward -3.433, speed 77.01 f/s
# 5443658: done 7735 episodes, mean reward -3.412, speed 110.18 f/s
# Test done in 4.74 sec, reward -3.620, steps 782
# 5444013: done 7736 episodes, mean reward -3.390, speed 44.59 f/s
# 5444930: done 7737 episodes, mean reward -3.403, speed 112.18 f/s
# Test done in 4.06 sec, reward -3.249, steps 680
# 5445441: done 7738 episodes, mean reward -3.396, speed 59.21 f/s
# Test done in 4.53 sec, reward -3.636, steps 764
# 5446150: done 7739 episodes, mean reward -3.415, speed 65.44 f/s
# 5446596: done 7740 episodes, mean reward -3.414, speed 111.82 f/s
# Test done in 3.21 sec, reward -3.099, steps 531
# 5447596: done 7741 episodes, mean reward -3.430, speed 82.44 f/s
# Test done in 4.00 sec, reward -3.659, steps 660
# 5448596: done 7742 episodes, mean reward -3.430, speed 76.92 f/s
# Test done in 3.78 sec, reward -3.185, steps 636
# 5449310: done 7743 episodes, mean reward -3.448, speed 70.43 f/s
# 5449935: done 7744 episodes, mean reward -3.462, speed 110.61 f/s
# Test done in 5.09 sec, reward -3.769, steps 849
# 5450298: done 7745 episodes, mean reward -3.462, speed 43.54 f/s
# 5450608: done 7746 episodes, mean reward -3.455, speed 112.78 f/s
# Test done in 4.41 sec, reward -3.435, steps 745
# 5451608: done 7747 episodes, mean reward -3.467, speed 75.24 f/s
# Test done in 3.81 sec, reward -3.236, steps 635
# 5452429: done 7748 episodes, mean reward -3.474, speed 73.73 f/s
# Test done in 4.19 sec, reward -3.285, steps 698
# 5453429: done 7749 episodes, mean reward -3.467, speed 76.84 f/s
# 5453972: done 7750 episodes, mean reward -3.474, speed 112.60 f/s
# Test done in 4.62 sec, reward -3.334, steps 775
# 5454913: done 7751 episodes, mean reward -3.496, speed 72.70 f/s
# Test done in 3.69 sec, reward -3.201, steps 623
# 5455191: done 7752 episodes, mean reward -3.492, speed 45.17 f/s
# 5455515: done 7753 episodes, mean reward -3.484, speed 112.16 f/s
# 5455973: done 7754 episodes, mean reward -3.488, speed 110.96 f/s
# Test done in 3.92 sec, reward -3.301, steps 653
# 5456387: done 7755 episodes, mean reward -3.475, speed 54.06 f/s
# Test done in 3.12 sec, reward -2.692, steps 526
# 5457387: done 7756 episodes, mean reward -3.495, speed 83.60 f/s
# 5457758: done 7757 episodes, mean reward -3.478, speed 112.57 f/s
# Test done in 4.18 sec, reward -3.103, steps 691
# 5458758: done 7758 episodes, mean reward -3.501, speed 76.29 f/s
# Test done in 4.02 sec, reward -3.340, steps 672
# 5459758: done 7759 episodes, mean reward -3.498, speed 77.11 f/s
# Test done in 4.88 sec, reward -3.595, steps 817
# 5460095: done 7760 episodes, mean reward -3.472, speed 42.78 f/s
# Test done in 4.22 sec, reward -3.633, steps 704
# 5461011: done 7761 episodes, mean reward -3.516, speed 74.10 f/s
# 5461820: done 7762 episodes, mean reward -3.528, speed 111.95 f/s
# Test done in 3.20 sec, reward -2.682, steps 517
# 5462150: done 7763 episodes, mean reward -3.530, speed 52.86 f/s
# 5462547: done 7764 episodes, mean reward -3.512, speed 107.40 f/s
# 5462939: done 7765 episodes, mean reward -3.484, speed 107.64 f/s
# Test done in 4.50 sec, reward -3.267, steps 747
# 5463436: done 7766 episodes, mean reward -3.474, speed 55.32 f/s
# 5463841: done 7767 episodes, mean reward -3.445, speed 111.62 f/s
# Test done in 3.95 sec, reward -3.221, steps 661
# 5464575: done 7768 episodes, mean reward -3.446, speed 69.69 f/s
# Test done in 3.33 sec, reward -2.775, steps 558
# 5465297: done 7769 episodes, mean reward -3.463, speed 73.87 f/s
# Test done in 4.08 sec, reward -3.566, steps 685
# 5466225: done 7770 episodes, mean reward -3.495, speed 75.11 f/s
# 5466636: done 7771 episodes, mean reward -3.464, speed 111.80 f/s
# Test done in 3.59 sec, reward -3.087, steps 603
# 5467001: done 7772 episodes, mean reward -3.467, speed 53.16 f/s
# Test done in 4.06 sec, reward -3.420, steps 680
# 5468001: done 7773 episodes, mean reward -3.476, speed 77.07 f/s
# 5468389: done 7774 episodes, mean reward -3.468, speed 111.27 f/s
# 5468674: done 7775 episodes, mean reward -3.440, speed 110.11 f/s
# Test done in 3.24 sec, reward -2.797, steps 542
# 5469521: done 7776 episodes, mean reward -3.461, speed 78.05 f/s
# Test done in 4.15 sec, reward -3.321, steps 693
# 5470521: done 7777 episodes, mean reward -3.479, speed 76.65 f/s
# Test done in 5.32 sec, reward -3.609, steps 893
# 5471521: done 7778 episodes, mean reward -3.498, speed 70.45 f/s
# 5471857: done 7779 episodes, mean reward -3.465, speed 108.44 f/s
# Test done in 3.87 sec, reward -3.063, steps 643
# 5472857: done 7780 episodes, mean reward -3.478, speed 78.10 f/s
# Test done in 3.03 sec, reward -2.407, steps 513
# 5473267: done 7781 episodes, mean reward -3.459, speed 61.39 f/s
# 5473633: done 7782 episodes, mean reward -3.457, speed 112.31 f/s
# Test done in 4.50 sec, reward -3.593, steps 757
# 5474633: done 7783 episodes, mean reward -3.470, speed 74.12 f/s
# Test done in 4.00 sec, reward -2.896, steps 666
# 5475085: done 7784 episodes, mean reward -3.462, speed 56.12 f/s
# 5475469: done 7785 episodes, mean reward -3.461, speed 112.69 f/s
# Test done in 3.67 sec, reward -2.739, steps 610
